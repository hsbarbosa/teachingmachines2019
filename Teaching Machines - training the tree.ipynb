# %%
# %reload_ext autoreload
# %autoreload 2
from DecisionTree import *
import pandas as pd

# %%
data = pd.read_csv("guess_data.csv",index_col=0)

# %%
df = pd.read_csv("guess_data.csv",index_col=0).drop(labels=['url'],axis=1)
df = df[df.columns[[0,1,2,3,4,5,6,8,7]]]

# %%
training_data = df.values.tolist()

# %%
header = df.columns.to_list()

# %%
df.head()
# Out:
#            access   clothe clotheColor       facialHair facialHairColor  \
# 0           Blank   Hoodie       Black            Blank             Red
# 1      Sunglasses   Hoodie        Pink  MoustacheMagnum           Black
# 2      Sunglasses  Overall         Red  MoustacheMagnum           Black
# 3  Prescription01  Overall  PastelBlue  MoustacheMagnum    BlondeGolden
# 4  Prescription01  Overall         Red  MoustacheMagnum    BlondeGolden
#
#            hair    mouth               top             name
# 0           Red      Sad  LongHairStraight  Michele Woodard
# 1  BlondeGolden      Sad            NoHair       James Skow
# 2         Black  Default            NoHair      Tim Saldana
# 3  BlondeGolden      Sad       LongHairFro     Robert Jones
# 4           Red  Serious       LongHairFro      Louis Baker

# %%
header
# Out:
# ['access',
#  'clothe',
#  'clotheColor',
#  'facialHair',
#  'facialHairColor',
#  'hair',
#  'mouth',
#  'top',
#  'name']

# %%
true_rows, false_rows = partition(training_data, Question(5, 'Red',header))
info_gain(true_rows, false_rows, current_uncertainty)
# Out:
# 0.02000000000000357

# %%
best_gain, best_question = find_best_split(training_data,header)
best_question
# Out:
# Is hair == Red?

# %%
df.head()
# Out:
#            access   clothe clotheColor       facialHair facialHairColor  \
# 0           Blank   Hoodie       Black            Blank             Red
# 1      Sunglasses   Hoodie        Pink  MoustacheMagnum           Black
# 2      Sunglasses  Overall         Red  MoustacheMagnum           Black
# 3  Prescription01  Overall  PastelBlue  MoustacheMagnum    BlondeGolden
# 4  Prescription01  Overall         Red  MoustacheMagnum    BlondeGolden
#
#            hair    mouth               top             name
# 0           Red      Sad  LongHairStraight  Michele Woodard
# 1  BlondeGolden      Sad            NoHair       James Skow
# 2         Black  Default            NoHair      Tim Saldana
# 3  BlondeGolden      Sad       LongHairFro     Robert Jones
# 4           Red  Serious       LongHairFro      Louis Baker

# %%
df.sample(n=1)
# Out:
#         access  clothe clotheColor       facialHair facialHairColor   hair  \
# 21  Sunglasses  Hoodie       Black  MoustacheMagnum    BlondeGolden  Black
#
#     mouth          top             name
# 21  Smile  LongHairFro  Steve Armstrong

# %%
df
# Out:
#             access         clothe clotheColor       facialHair  \
# 0            Blank         Hoodie       Black            Blank
# 1       Sunglasses         Hoodie        Pink  MoustacheMagnum
# 2       Sunglasses        Overall         Red  MoustacheMagnum
# 3   Prescription01        Overall  PastelBlue  MoustacheMagnum
# 4   Prescription01        Overall         Red  MoustacheMagnum
# 5       Sunglasses         Hoodie         Red            Blank
# 6   Prescription01         Hoodie         Red  MoustacheMagnum
# 7       Sunglasses        Overall       Black  MoustacheMagnum
# 8       Sunglasses         Hoodie       Black            Blank
# 9   Prescription01  ShirtCrewNeck       Black            Blank
# 10           Blank        Overall         Red            Blank
# 11      Sunglasses         Hoodie  PastelBlue  MoustacheMagnum
# 12      Sunglasses        Overall       Black  MoustacheMagnum
# 13  Prescription01  ShirtCrewNeck         Red  MoustacheMagnum
# ...

# %%
my_tree = build_tree(training_data,header)

# %%
first_row = """ <tr>
      <th>name</th>
    <th>access</th>
    <th>clothe</th>
    <th>clotheColor</th>
    <th>facialHair</th>
    <th>facialHairColor</th>
    <th>hair</th>
    <th>mouth</th>
    <th>top</th>  
    <th>photo</th>  
  </tr>
  <tr>
  {rows_data}
  </tr>
  """
  
row_base = "<td>{data}</td>\n"
img_base = "<img src='{url}' width='400'/>"
rows_data = ""
for index,row in data.iterrows():
    rows_data += "<tr>"+row_base.format(data=row['name'])+\
        row_base.format(data=row['access'])+\
        row_base.format(data=row['clothe'])+\
        row_base.format(data=row['clotheColor']) +\
        row_base.format(data=row['facialHair']) +\
        row_base.format(data=row['facialHairColor']) +\
        row_base.format(data=row['hair'])+\
        row_base.format(data=row['mouth'])+\
        row_base.format(data=row['top'])+\
        row_base.format(data=img_base.format(url=row['url']))+\
        "</tr>"

# %%
first_row = """
  <tr>
  {rows_data}
  </tr>
  """
  
row_base = "<td>{data}</td>\n"
img_base = "<img src='{url}' width='100'><center>{name}</center></img>"
table_data = ""
rows_data = ""
for index,row in data.iterrows():
    rows_data += row_base.format(data=img_base.format(url=row['url'],name=row['name']))
    if index%5==4:
        rows_data = "<tr>"+rows_data+"</tr>"
        table_data+= rows_data
        rows_data  = ""

# %% [markdown]
# <tr>
#       <th>name</th>
#     <th>access</th>
#     <th>clothe</th>
#     <th>clotheColor</th>
#     <th>facialHair</th>
#     <th>facialHairColor</th>
#     <th>hair</th>
#     <th>mouth</th>
#     <th>top</th>
#     <th>photo</th>
#   </tr>
#   <tr>
#   <tr><td>Michele Woodard</td>
# <td>Blank</td>
# <td>Hoodie</td>
# <td>Black</td>
# <td>Blank</td>
# <td>Red</td>
# <td>Red</td>
# <td>Sad</td>
# <td>LongHairStraight</td>
# <td><img src='https://avataaars.io/?avatarStyle=Transparent&clotheColor=Black&mouthType=Sad&topType=LongHairStraight&accessoriesType=Blank&hairColor=Red&facialHairType=Blank&facialHairColor=Red&clotheType=Hoodie' width='400'/></td>
# </tr><tr><td>James Skow</td>
# <td>Sunglasses</td>
# <td>Hoodie</td>
# <td>Pink</td>
# <td>MoustacheMagnum</td>
# <td>Black</td>
# <td>BlondeGolden</td>
# <td>Sad</td>
# <td>NoHair</td>
# <td><img src='https://avataaars.io/?avatarStyle=Transparent&clotheColor=Pink&mouthType=Sad&topType=NoHair&accessoriesType=Sunglasses&hairColor=BlondeGolden&facialHairType=MoustacheMagnum&facialHairColor=Black&clotheType=Hoodie' width='400'/></td>
# </tr><tr><td>Tim Saldana</td>
# <td>Sunglasses</td>
# <td>Overall</td>
# <td>Red</td>
# <td>MoustacheMagnum</td>
# <td>Black</td>
# <td>Black</td>
# <td>Default</td>
# <td>NoHair</td>
# <td><img src='https://avataaars.io/?avatarStyle=Transparent&clotheColor=Red&mouthType=Default&topType=NoHair&accessoriesType=Sunglasses&hairColor=Black&facialHairType=MoustacheMagnum&facialHairColor=Black&clotheType=Overall' width='400'/></td>
# </tr><tr><td>
td>
# <td><img src='https://avataaars.io/?avatarStyle=Transparent&clotheColor=Pink&mouthType=Sad&topType=NoHair&accessoriesType=Prescription01&hairColor=BlondeGolden&facialHairType=MoustacheMagnum&facialHairColor=BlondeGolden&clotheType=Hoodie' width='400'/></td>
# </tr><tr><td>Terrell Thayer</td>
# <td>Sunglasses</td>
# <td>Hoodie</td>
# <td>Red</td>
# <td>Blank</td>
# <td>Black</td>
# <td>Black</td>
# <td>Smile</td>
# <td>LongHairBun</td>
# <td><img src='https://avataaars.io/?avatarStyle=Transparent&clotheColor=Red&mouthType=Smile&topType=LongHairBun&accessoriesType=Sunglasses&hairColor=Black&facialHairType=Blank&facialHairColor=Black&clotheType=Hoodie' width='400'/></td>
# </tr><tr><td>Terry Polowy</td>
# <td>Sunglasses</td>
# <td>Overall</td>
# <td>Red</td>
# <td>Blank</td>
# <td>Red</td>
# <td>BlondeGolden</td>
# <td>Default</td>
# <td>LongHairBun</td>
# <td><img src='https://avataaars.io/?avatarStyle=Transparent&clotheColor=Red&mouthType=Default&topType=LongHairBun&accessoriesType=Sunglasses&hairColor=BlondeGolden&facialHairType=Blank&facialHairColor=Red&clotheType=Overall' width='400'/></td>
# </tr><tr><td>Heather Dukes</td>
# <td>Prescription01</td>
# <td>Overall</td>
# <td>Pink</td>
# <td>Blank</td>
# <td>Black</td>
# <td>Black</td>
# <td>Serious</td>
# <td>LongHairBun</td>
# <td><img src='https://avataaars.io/?avatarStyle=Transparent&clotheColor=Pink&mouthType=Serious&topType=LongHairBun&accessoriesType=Prescription01&hairColor=Black&facialHairType=Blank&facialHairColor=Black&clotheType=Overall' width='400'/></td>
# </tr><tr><td>Lewis Evans</td>
# <td>Blank</td>
# <td>Hoodie</td>
# <td>Black</td>
# <td>MoustacheMagnum</td>
# <td>Red</td>
# <td>Black</td>
# <td>Smile</td>
# <td>LongHairStraight</td>
# <td><img src='https://avataaars.io/?avatarStyle=Transparent&clotheColor=Black&mouthType=Smile&topType=LongHairStraight&accessoriesType=Blank&hairColor=Black&facialHairType=MoustacheMagnum&facialHairColor=Red&clotheType=Hoodie' width='400'/></td>
# </tr><tr><td>Jane Kirby</td>
# <td>Blank</td>
# <td>Hoodie</td>
# <td>Red</td>
# <td>MoustacheMagnum</td>
# <td>BlondeGolden</td>
# <td>Red</td>
# <td>Smile</td>
# <td>LongHairBun</td>
# <td><img src='https://avataaars.io/?avatarStyle=Transparent&clotheColor=Red&mouthType=Smile&topType=LongHairBun&accessoriesType=Blank&hairColor=Red&facialHairType=MoustacheMagnum&facialHairColor=BlondeGolden&clotheType=Hoodie' width='400'/></td>
# </tr><tr><td>Davis Helbert</td>
# <td>Sunglasses</td>
# <td>Hoodie</td>
# <td>Pink</td>
# <td>MoustacheMagnum</td>
# <td>Black</td>
# <td>Red</td>
# <td>Default</td>
# <td>LongHairBun</td>
# <td><img src='https://avataaars.io/?avatarStyle=Transparent&clotheColor=Pink&mouthType=Default&topType=LongHairBun&accessoriesType=Sunglasses&hairColor=Red&facialHairType=MoustacheMagnum&facialHairColor=Black&clotheType=Hoodie' width='400'/></td>
# </tr>
#   </tr>

# %%
a ="""
<img src='https://avataaars.io/?avatarStyle=Circle&topType=LongHairStraight&accessoriesType=Blank&hairColor=BrownDark&facialHairType=Blank&clotheType=BlazerShirt&eyeType=Default&eyebrowType=Default&mouthType=Default&skinColor=Light'
/>"""

# %%
def proc_img(a):
    a = a[:-4].strip().split('&')[1:]
    a = list(map(lambda x:tuple(x.split('=')),a))
    return dict(a)

# %%
proc_img(a)
# Out:
# {'topType': 'LongHairStraight',
#  'accessoriesType': 'Blank',
#  'hairColor': 'BrownDark',
#  'facialHairType': 'Blank',
#  'clotheType': 'BlazerShirt',
#  'eyeType': 'Default',
#  'eyebrowType': 'Default',
#  'mouthType': 'Default',
#  'skinColor': 'Light'}
